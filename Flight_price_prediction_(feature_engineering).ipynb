# %% [markdown]
# <a href="https://colab.research.google.com/github/mamun216/Exploratory-data-analysis/blob/main/Flight_price_prediction_(feature_engineering).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Flight price prediction(EDA & Feature engineering)

# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
# Mount the drive to load the data
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Loading dataset

# %%
train_df = pd.read_excel('/content/drive/MyDrive/Data_Train.xlsx')
train_df.head()
# Out:
#        Airline Date_of_Journey    Source  ... Total_Stops Additional_Info  Price
# 0       IndiGo      24/03/2019  Banglore  ...    non-stop         No info   3897
# 1    Air India       1/05/2019   Kolkata  ...     2 stops         No info   7662
# 2  Jet Airways       9/06/2019     Delhi  ...     2 stops         No info  13882
# 3       IndiGo      12/05/2019   Kolkata  ...      1 stop         No info   6218
# 4       IndiGo      01/03/2019  Banglore  ...      1 stop         No info  13302
#
# [5 rows x 11 columns]

# %%
test_df = pd.read_excel('/content/drive/MyDrive/Test_set.xlsx')
test_df.head()
# Out:
#              Airline Date_of_Journey  ... Total_Stops              Additional_Info
# 0        Jet Airways       6/06/2019  ...      1 stop                      No info
# 1             IndiGo      12/05/2019  ...      1 stop                      No info
# 2        Jet Airways      21/05/2019  ...      1 stop  In-flight meal not included
# 3  Multiple carriers      21/05/2019  ...      1 stop                      No info
# 4           Air Asia      24/06/2019  ...    non-stop                      No info
#
# [5 rows x 10 columns]

# %%
# Merge both train and test data by appending method
df = train_df.append(test_df)
df.head()
# Out:
#        Airline Date_of_Journey    Source  ... Total_Stops Additional_Info    Price
# 0       IndiGo      24/03/2019  Banglore  ...    non-stop         No info   3897.0
# 1    Air India       1/05/2019   Kolkata  ...     2 stops         No info   7662.0
# 2  Jet Airways       9/06/2019     Delhi  ...     2 stops         No info  13882.0
# 3       IndiGo      12/05/2019   Kolkata  ...      1 stop         No info   6218.0
# 4       IndiGo      01/03/2019  Banglore  ...      1 stop         No info  13302.0
#
# [5 rows x 11 columns]

# %%
df.tail()
# Out:
#                 Airline Date_of_Journey  ... Additional_Info Price
# 2666          Air India       6/06/2019  ...         No info   NaN
# 2667             IndiGo      27/03/2019  ...         No info   NaN
# 2668        Jet Airways       6/03/2019  ...         No info   NaN
# 2669          Air India       6/03/2019  ...         No info   NaN
# 2670  Multiple carriers      15/06/2019  ...         No info   NaN
#
# [5 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Additional_Info  13354 non-null  object
#  10  Price            10683 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 1.2+ MB

# %% [markdown]
# # Feature engineering

# %% [markdown]
# ## Date of journey
# This feature contain day, month and year value in object form. We will sort out as different individual feature as date, month and year.

# %%
# split date of journey column into date, month and year
df['Date'] = df['Date_of_Journey'].str.split('/').str[0]
df['Month'] = df['Date_of_Journey'].str.split('/').str[1]
df['Year'] = df['Date_of_Journey'].str.split('/').str[2]

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination  ...    Price Date Month  Year
# 0       IndiGo      24/03/2019  Banglore   New Delhi  ...   3897.0   24    03  2019
# 1    Air India       1/05/2019   Kolkata    Banglore  ...   7662.0    1    05  2019
# 2  Jet Airways       9/06/2019     Delhi      Cochin  ...  13882.0    9    06  2019
# 3       IndiGo      12/05/2019   Kolkata    Banglore  ...   6218.0   12    05  2019
# 4       IndiGo      01/03/2019  Banglore   New Delhi  ...  13302.0   01    03  2019
#
# [5 rows x 14 columns]

# %%
# Convert data type to integer
df['Date'] = df['Date'].astype(int)
df['Month'] = df['Month'].astype(int)
df['Year'] = df['Year'].astype(int)

# %%
# Drop the original column Date of journey
df.drop('Date_of_Journey', axis = 1, inplace = True)

# %% [markdown]
# ## Arrival_time
# This feature contain hour and minute together. We will seperate hour and minute in two columns.

# %%
# Find the arrival time only
df['Arrival_Time'] = df['Arrival_Time'].str.split().str[0]

# %%
df.head()
# Out:
#        Airline    Source Destination  ... Date Month  Year
# 0       IndiGo  Banglore   New Delhi  ...   24     3  2019
# 1    Air India   Kolkata    Banglore  ...    1     5  2019
# 2  Jet Airways     Delhi      Cochin  ...    9     6  2019
# 3       IndiGo   Kolkata    Banglore  ...   12     5  2019
# 4       IndiGo  Banglore   New Delhi  ...    1     3  2019
#
# [5 rows x 13 columns]

# %%
# Split the Arrival_time column into hour and minute
df['Arrival_hour'] = df['Arrival_Time'].str.split(':').str[0]
df['Arrival_minute'] = df['Arrival_Time'].str.split(':').str[1]

# %%
# Convert datatype into integer
df['Arrival_hour'] = df['Arrival_hour'].astype(int)
df['Arrival_minute'] = df['Arrival_minute'].astype(int)

# %%
# Drop the Arrival time column
df.drop('Arrival_Time', axis = 1, inplace = True)

# %% [markdown]
# ## Departure Time
# As the same way we did for Arrival time we will make new columns as dep_hour and dep_minute, convert the datatype into integer and then drop the original column.

# %%
df['Dep_hour'] = df['Dep_Time'].str.split(':').str[0]
df['Dep_minute'] = df['Dep_Time'].str.split(':').str[1]
df['Dep_hour'] = df['Dep_hour'].astype(int)
df['Dep_minute'] = df['Dep_minute'].astype(int)
df.drop('Dep_Time', axis = 1, inplace = True)

# %%
df.isnull().sum()
# Out:
# Airline               0
# Source                0
# Destination           0
# Route                 1
# Duration              0
# Total_Stops           1
# Additional_Info       0
# Price              2671
# Date                  0
# Month                 0
# Year                  0
# Arrival_hour          0
# Arrival_minute        0
# Dep_hour              0
# Dep_minute            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Route            13353 non-null  object
#  4   Duration         13354 non-null  object
#  5   Total_Stops      13353 non-null  object
#  6   Additional_Info  13354 non-null  object
#  7   Price            10683 non-null  float64
#  8   Date             13354 non-null  int64
#  9   Month            13354 non-null  int64
#  10  Year             13354 non-null  int64
#  11  Arrival_hour     13354 non-null  int64
#  12  Arrival_minute   13354 non-null  int64
#  13  Dep_hour         13354 non-null  int64
#  14  Dep_minute       13354 non-null  int64
# dtypes: float64(1), int64(7), object(7)
# memory usage: 1.6+ MB

# %% [markdown]
# ## Total_stops
# Convert this feature into numeric format.

# %%
# Show the unique values 
df['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops'],
#       dtype=object)

# %%
# Check which value has none
df[df['Total_Stops'].isnull()]
# Out:
#         Airline Source Destination  ... Arrival_minute Dep_hour Dep_minute
# 9039  Air India  Delhi      Cochin  ...             25        9         45
#
# [1 rows x 15 columns]

# %%
# Mapping Total_stops variable to make machine feedable discrete data
df['Total_Stops'] = df['Total_Stops'].map({'non-stop':0, '1 stop':1,'2 stops':2, '3 stops':3,'4 stops':4, 'nan':1})
df.head()
# Out:
#        Airline    Source Destination  ... Arrival_minute Dep_hour  Dep_minute
# 0       IndiGo  Banglore   New Delhi  ...             10       22          20
# 1    Air India   Kolkata    Banglore  ...             15        5          50
# 2  Jet Airways     Delhi      Cochin  ...             25        9          25
# 3       IndiGo   Kolkata    Banglore  ...             30       18           5
# 4       IndiGo  Banglore   New Delhi  ...             35       16          50
#
# [5 rows x 15 columns]

# %%
# drop the route feature which is not needed as we have total no of stops and source and destination features.
df.drop('Route', axis = 1, inplace = True)

# %%
df.head()
# Out:
#        Airline    Source Destination  ... Arrival_minute  Dep_hour Dep_minute
# 0       IndiGo  Banglore   New Delhi  ...             10        22         20
# 1    Air India   Kolkata    Banglore  ...             15         5         50
# 2  Jet Airways     Delhi      Cochin  ...             25         9         25
# 3       IndiGo   Kolkata    Banglore  ...             30        18          5
# 4       IndiGo  Banglore   New Delhi  ...             35        16         50
#
# [5 rows x 14 columns]

# %% [markdown]
# ## Duration_hour
# Keep the hour and minute separate in numeric format from this feature.

# %%
df['Duration_hour'] = df['Duration'].str.split(' ').str[0].str.split('h').str[0]

# %%
df[df['Duration_hour']=='5m']
# Out:
#         Airline  Source Destination  ... Dep_hour  Dep_minute Duration_hour
# 6474  Air India  Mumbai   Hyderabad  ...       16          50            5m
# 2660  Air India  Mumbai   Hyderabad  ...       16          50            5m
#
# [2 rows x 15 columns]

# %%
# drop the rows which contain value with hour
df.drop(6474, axis = 0, inplace = True)
df.drop(2660, axis = 0, inplace = True)

# %%
df['Duration_hour'] = df['Duration_hour'].astype(int)

# %%
df['Duration_minute'] = df['Duration'].str.split(' ').str[1].str.split('m').str[0]

# %%
df['Duration_minute'].value_counts()
# Out:
# 30    1818
# 20    1260
# 50    1205
# 45    1154
# 35    1149
# 15    1135
# 55    1121
# 25    1009
# 40     803
# 5      767
# 10     647
# Name: Duration_minute, dtype: int64

# %%
df['Duration_minute']= df['Duration_minute'].replace(np.nan, 0)

# %%
df['Duration_minute'] = df['Duration_minute'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13351 entries, 0 to 2670
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13351 non-null  object
#  1   Source           13351 non-null  object
#  2   Destination      13351 non-null  object
#  3   Duration         13351 non-null  object
#  4   Total_Stops      13350 non-null  float64
#  5   Additional_Info  13351 non-null  object
#  6   Price            10681 non-null  float64
#  7   Date             13351 non-null  int64
#  8   Month            13351 non-null  int64
#  9   Year             13351 non-null  int64
#  10  Arrival_hour     13351 non-null  int64
#  11  Arrival_minute   13351 non-null  int64
#  12  Dep_hour         13351 non-null  int64
#  13  Dep_minute       13351 non-null  int64
#  14  Duration_hour    13351 non-null  int64
#  15  Duration_minute  13351 non-null  int64
# dtypes: float64(2), int64(9), object(5)
# ...

# %%
df.drop('Duration', axis =1, inplace = True)

# %%
df.head(2)
# Out:
#      Airline    Source Destination  ...  Dep_minute Duration_hour  Duration_minute
# 0     IndiGo  Banglore   New Delhi  ...          20             2               50
# 1  Air India   Kolkata    Banglore  ...          50             7               25
#
# [2 rows x 15 columns]

# %% [markdown]
# # Feature engineering on remaining categorical feature

# %%
# Categorical feature
df['Airline'].unique()
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()

df['Airline'] = labelencoder.fit_transform(df['Airline'])
df['Source'] = labelencoder.fit_transform(df['Source'])
df['Destination'] = labelencoder.fit_transform(df['Destination'])
df['Additional_Info'] = labelencoder.fit_transform(df['Additional_Info'])

# %%
# from sklearn.preprocessing import OneHotEncoder
# one = OneHotEncoder()

# df['Airline'] = one.fit_transform(df['Airline'])
# df['Source'] = one.fit_transform(df['Source'])
# df['Destination'] = one.fit_transform(df['Destination'])
# df['Additional_Info'] = one.fit_transform(df['Additional_Info'])

# %%
df.head()
# Out:
#    Airline  Source  Destination  ...  Dep_minute  Duration_hour  Duration_minute
# 0        3       0            5  ...          20              2               50
# 1        1       3            0  ...          50              7               25
# 2        4       2            1  ...          25             19                0
# 3        3       3            0  ...           5              5               25
# 4        3       0            5  ...          50              4               45
#
# [5 rows x 15 columns]

# %%
# Also use get dummies method
#pd.get_dummies(df, columns = ['Airline', 'Source', 'Destination', 'Additional_Info'], drop_first = True)
# Out:
#       Total_Stops    Price  ...  Additional_Info_8  Additional_Info_9
# 0             0.0   3897.0  ...                  1                  0
# 1             2.0   7662.0  ...                  1                  0
# 2             2.0  13882.0  ...                  1                  0
# 3             1.0   6218.0  ...                  1                  0
# 4             1.0  13302.0  ...                  1                  0
# ...           ...      ...  ...                ...                ...
# 2666          1.0      NaN  ...                  1                  0
# 2667          0.0      NaN  ...                  1                  0
# 2668          1.0      NaN  ...                  1                  0
# 2669          1.0      NaN  ...                  1                  0
# 2670          1.0      NaN  ...                  1                  0
#
# [13351 rows x 40 columns]

# %%
# Show the statistical distribution
df.describe()
# Out:
#             Airline        Source  ...  Duration_hour  Duration_minute
# count  13351.000000  13351.000000  ...   13351.000000     13351.000000
# mean       3.977530      1.953786  ...      10.234964        28.347315
# std        2.363982      1.178474  ...       8.473072        16.903136
# min        0.000000      0.000000  ...       1.000000         0.000000
# 25%        3.000000      2.000000  ...       2.000000        15.000000
# 50%        4.000000      2.000000  ...       8.000000        30.000000
# 75%        4.000000      3.000000  ...      15.000000        45.000000
# max       11.000000      4.000000  ...      47.000000        55.000000
#
# [8 rows x 15 columns]

# %%
plt.figure(figsize =(15,10))
sns.heatmap(df.corr(), annot = True);

# %% [markdown]
# # Conclusion
# As this project was only feature engineering task, so did data mungling for machine readble to train the model.
